# %%
import pandas as pd

# %%
file = 'Resources/movies_metadata.csv'

# %%
df = pd.read_csv(file)
df.head()
# Out:
# /Users/daltonfield/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# ...

# %%
df.count()
# Out:
# adult                    45466
# belongs_to_collection     4494
# budget                   45466
# genres                   45466
# homepage                  7782
# id                       45466
# imdb_id                  45449
# original_language        45455
# original_title           45466
# overview                 44512
# popularity               45461
# poster_path              45080
# production_companies     45463
# production_countries     45463
# release_date             45379
# revenue                  45460
# runtime                  45203
# spoken_languages         45460
# status                   45379
# tagline                  20412
# title                    45460
# video                    45460
# vote_average             45460
# vote_count               45460
# dtype: int64

# %%
df = df[["title","release_date" ,"budget", "revenue", "vote_average"]]

# %%
df.head()
# Out:
#                          title release_date    budget      revenue  \
# 0                    Toy Story   1995-10-30  30000000  373554033.0
# 1                      Jumanji   1995-12-15  65000000  262797249.0
# 2             Grumpier Old Men   1995-12-22         0          0.0
# 3            Waiting to Exhale   1995-12-22  16000000   81452156.0
# 4  Father of the Bride Part II   1995-02-10         0   76578911.0
#
#    vote_average
# 0           7.7
# 1           6.9
# 2           6.5
# 3           6.1
# 4           5.7

# %%
df.count()
# Out:
# title           45460
# release_date    45379
# budget          45466
# revenue         45460
# vote_average    45460
# dtype: int64

# %%
df = df.dropna(how='any')
df.head()
# Out:
#                          title release_date    budget      revenue  \
# 0                    Toy Story   1995-10-30  30000000  373554033.0
# 1                      Jumanji   1995-12-15  65000000  262797249.0
# 2             Grumpier Old Men   1995-12-22         0          0.0
# 3            Waiting to Exhale   1995-12-22  16000000   81452156.0
# 4  Father of the Bride Part II   1995-02-10         0   76578911.0
#
#    vote_average
# 0           7.7
# 1           6.9
# 2           6.5
# 3           6.1
# 4           5.7

# %%
df.count()
# Out:
# title           45376
# release_date    45376
# budget          45376
# revenue         45376
# vote_average    45376
# dtype: int64

# %%
df = df.rename(columns={"title":"Title","release_date":"Year" , "budget":"Budget", "revenue":"Revenue","vote_average":"Average Vote"})

# %%
df.head()
# Out:
#                          Title        Year    Budget      Revenue  \
# 0                    Toy Story  1995-10-30  30000000  373554033.0
# 1                      Jumanji  1995-12-15  65000000  262797249.0
# 2             Grumpier Old Men  1995-12-22         0          0.0
# 3            Waiting to Exhale  1995-12-22  16000000   81452156.0
# 4  Father of the Bride Part II  1995-02-10         0   76578911.0
#
#    Average Vote
# 0           7.7
# 1           6.9
# 2           6.5
# 3           6.1
# 4           5.7

# %%
indexbudget = df[df['Budget'] == '0'].index
df.drop(indexbudget , inplace=True)

# %%
indexrevenue = df[df['Revenue'] == 0.0].index
df.drop(indexrevenue , inplace=True)

# %%
df.head()
# Out:
#                Title        Year    Budget      Revenue  Average Vote
# 0          Toy Story  1995-10-30  30000000  373554033.0           7.7
# 1            Jumanji  1995-12-15  65000000  262797249.0           6.9
# 3  Waiting to Exhale  1995-12-22  16000000   81452156.0           6.1
# 5               Heat  1995-12-15  60000000  187436818.0           7.7
# 8       Sudden Death  1995-12-22  35000000   64350171.0           5.5

# %%
df.count()
# Out:
# Title           5381
# Year            5381
# Budget          5381
# Revenue         5381
# Average Vote    5381
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5381 entries, 0 to 45422
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         5381 non-null   object
#  1   Year          5381 non-null   object
#  2   Budget        5381 non-null   object
#  3   Revenue       5381 non-null   float64
#  4   Average Vote  5381 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 252.2+ KB

# %%
df["Budget"] = df["Budget"].astype(float)

# %%
gross_revenue = df["Revenue"] + df["Budget"]

# %%
df["Gross Revenue"] = gross_revenue

# %%
df.head()
# Out:
#                Title        Year      Budget      Revenue  Average Vote  \
# 0          Toy Story  1995-10-30  30000000.0  373554033.0           7.7
# 1            Jumanji  1995-12-15  65000000.0  262797249.0           6.9
# 3  Waiting to Exhale  1995-12-22  16000000.0   81452156.0           6.1
# 5               Heat  1995-12-15  60000000.0  187436818.0           7.7
# 8       Sudden Death  1995-12-22  35000000.0   64350171.0           5.5
#
#    Gross Revenue
# 0    403554033.0
# 1    327797249.0
# 3     97452156.0
# 5    247436818.0
# 8     99350171.0

# %%
df = df[["Title","Year" ,"Budget","Revenue","Gross Revenue", "Average Vote"]]
df.head()
# Out:
#                Title        Year      Budget      Revenue  Gross Revenue  \
# 0          Toy Story  1995-10-30  30000000.0  373554033.0    403554033.0
# 1            Jumanji  1995-12-15  65000000.0  262797249.0    327797249.0
# 3  Waiting to Exhale  1995-12-22  16000000.0   81452156.0     97452156.0
# 5               Heat  1995-12-15  60000000.0  187436818.0    247436818.0
# 8       Sudden Death  1995-12-22  35000000.0   64350171.0     99350171.0
#
#    Average Vote
# 0           7.7
# 1           6.9
# 3           6.1
# 5           7.7
# 8           5.5

# %%
new = df["Year"].str.split("-", n=1, expand = True)
df["Year"] = new[0]

# %%
df.head()
# Out:
#                Title  Year      Budget      Revenue  Gross Revenue  \
# 0          Toy Story  1995  30000000.0  373554033.0    403554033.0
# 1            Jumanji  1995  65000000.0  262797249.0    327797249.0
# 3  Waiting to Exhale  1995  16000000.0   81452156.0     97452156.0
# 5               Heat  1995  60000000.0  187436818.0    247436818.0
# 8       Sudden Death  1995  35000000.0   64350171.0     99350171.0
#
#    Average Vote
# 0           7.7
# 1           6.9
# 3           6.1
# 5           7.7
# 8           5.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5381 entries, 0 to 45422
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          5381 non-null   object
#  1   Year           5381 non-null   object
#  2   Budget         5381 non-null   float64
#  3   Revenue        5381 non-null   float64
#  4   Gross Revenue  5381 non-null   float64
#  5   Average Vote   5381 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 294.3+ KB

# %%
df["Year"] = df["Year"].astype(int)

# %%
df = df[(df["Year"]>1989)]

# %%
df = df[(df["Year"]<2000)]

# %%
df.head(10)
# Out:
#                      Title  Year      Budget      Revenue  Gross Revenue  \
# 0                Toy Story  1995  30000000.0  373554033.0    403554033.0
# 1                  Jumanji  1995  65000000.0  262797249.0    327797249.0
# 3        Waiting to Exhale  1995  16000000.0   81452156.0     97452156.0
# 5                     Heat  1995  60000000.0  187436818.0    247436818.0
# 8             Sudden Death  1995  35000000.0   64350171.0     99350171.0
# 9                GoldenEye  1995  58000000.0  352194034.0    410194034.0
# 10  The American President  1995  62000000.0  107879496.0    169879496.0
# 13                   Nixon  1995  44000000.0   13681765.0     57681765.0
# 14        Cutthroat Island  1995  98000000.0   10017322.0    108017322.0
# 15                  Casino  1995  52000000.0  116112375.0    168112375.0
#
#     Average Vote
# 0            7.7
# 1            6.9
# 3            6.1
# 5            7.7
# 8            5.5
# 9            6.6
# 10           6.5
# ...

# %%
df.to_csv('meta_data_cleaned_final.csv')
