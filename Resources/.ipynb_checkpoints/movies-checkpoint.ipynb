# %%
# Dependencies
import pandas as pd
import datetime as dt

# %%
# Name of the CSV file
file = 'IMDb movies.csv'

# %%
movies_df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
# Preview of the DataFrame
movies_df
# Out:
#       imdb_title_id                                              title  \
# 0         tt0000574                        The Story of the Kelly Gang
# 1         tt0001892                                    Den sorte drÃ¸m
# 2         tt0002101                                          Cleopatra
# 3         tt0002130                                          L'Inferno
# 4         tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# ...             ...                                                ...
# 81268     tt9903716                                             Jessie
# 81269     tt9905412                                              Ottam
# 81270     tt9905462                                          Pengalila
# 81271     tt9911774                          Padmavyuhathile Abhimanyu
# 81272     tt9914286                                 Sokagin Ãocuklari
#
#                                           original_title  year date_published  \
# ...

# %%
movies_df.count()
# Out:
# imdb_title_id            81273
# title                    81273
# original_title           81273
# year                     81273
# date_published           81273
# genre                    81273
# duration                 81273
# country                  81234
# language                 80518
# director                 81200
# writer                   79780
# production_company       76948
# actors                   81207
# description              78843
# avg_vote                 81273
# votes                    81273
# budget                   22804
# usa_gross_income         15094
# worlwide_gross_income    29892
# metascore                12722
# reviews_from_users       74196
# reviews_from_critics     70286
# dtype: int64

# %%
movies_df.dropna()
# Out:
#       imdb_title_id                            title  \
# 488       tt0017136                       Metropolis
# 1005      tt0021749                      City Lights
# 2336      tt0027977                     Modern Times
# 2687      tt0029583  Snow White and the Seven Dwarfs
# 3100      tt0031381               Gone with the Wind
# ...             ...                              ...
# 80665     tt8772262                        Midsommar
# 80858     tt9024106                        Unplanned
# 80908     tt9082020                Cold Blood Legacy
# 80946     tt9134216                Playing with Fire
# 81059     tt9354944                             Jexi
#
#                         original_title  year date_published  \
# 488                         Metropolis  1927     1927-02-06
# 1005                       City Lights  1931     1931-08-21
# 2336                      Modern Times  1936     1936-10-16
# 2687   Snow White and the Seven Dwarfs  1937     1938-07-08
# ...

# %%
movies_df_clean=movies_df[['title', 'year','budget', 'worlwide_gross_income']].dropna()
movies_df_clean=movies_df_clean.reset_index()
movies_df_clean.head()
# Out:
#    index                                title  year      budget  \
# 0    155         Das Cabinet des Dr. Caligari  1920     $ 18000
# 1    198                       Markens grÃ¸de  1921  NOK 250000
# 2    232  The Four Horsemen of the Apocalypse  1921    $ 800000
# 3    238                              The Kid  1921    $ 250000
# 4    334    A Woman of Paris: A Drama of Fate  1923    $ 351000
#
#   worlwide_gross_income
# 0                $ 8811
# 1                $ 4272
# 2             $ 9183673
# 3               $ 26916
# 4               $ 11233

# %%
#movies_df_clean['year'].dt.year
movies_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12475 entries, 0 to 12474
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  12475 non-null  int64
#  1   title                  12475 non-null  object
#  2   year                   12475 non-null  int64
#  3   budget                 12475 non-null  object
#  4   worlwide_gross_income  12475 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 487.4+ KB

# %%
# Name = movies_df_clean[movies_df_clean["year"]> 1989 ].index
# df.drop(Name , inplace=True)
# Name_2 = movies_df_clean[movies_df_clean["year"] <2000].index
# df.drop(Name_2 , inplace=True)

# %%
movies_df_clean
# Out:
#        index                                title  year        budget  \
# 0        155         Das Cabinet des Dr. Caligari  1920       $ 18000
# 1        198                       Markens grÃ¸de  1921    NOK 250000
# 2        232  The Four Horsemen of the Apocalypse  1921      $ 800000
# 3        238                              The Kid  1921      $ 250000
# 4        334    A Woman of Paris: A Drama of Fate  1923      $ 351000
# ...      ...                                  ...   ...           ...
# 12470  81234                 Krasue: Inhuman Kiss  2019     $ 1200000
# 12471  81261                          Subharathri  2019  INR 30000000
# 12472  81264   Upin & Ipin: Keris Siamang Tunggal  2019  MYR 20000000
# 12473  81267                               Kaithi  2019     $ 6000000
# 12474  81269                                Ottam  2019   INR 4000000
#
#       worlwide_gross_income
# 0                    $ 8811
# 1                    $ 4272
# 2                 $ 9183673
# ...

# %%
movies_dates_clean=movies_df_clean[(movies_df_clean['year']< 2000)]

movies_dates_clean
# Out:
#       index                                              title  year  \
# 0       155                       Das Cabinet des Dr. Caligari  1920
# 1       198                                     Markens grÃ¸de  1921
# 2       232                The Four Horsemen of the Apocalypse  1921
# 3       238                                            The Kid  1921
# 4       334                  A Woman of Paris: A Drama of Fate  1923
# ...     ...                                                ...   ...
# 3306  35466  GekijÃ´-ban poketto monsutÃ¢: Maboroshi no pok...  1999
# 3349  35854                                            Ringu 2  1999
# 3371  35996                                               ABCD  1999
# 3372  36019                                     Los sin nombre  1999
# 4082  40363                       Sarangbang sonnimgwa eomeoni  1961
#
#             budget worlwide_gross_income
# 0          $ 18000                $ 8811
# 1       NOK 250000                $ 4272
# ...

# %%
movies_dates_clean_2=movies_dates_clean[(movies_df_clean['year']> 1989)]
movies_dates_clean_2
# Out:
# C:\Users\hanso\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       index                                              title  year  \
# 1434  24178                             Spontaneous Combustion  1990
# 1453  24301                    The Adventures of Ford Fairlane  1990
# 1454  24308                                        Air America  1990
# 1455  24310                                              Alice  1990
# 1456  24313                                    Almost an Angel  1990
# ...     ...                                                ...   ...
# 3280  35234                         Deuce Bigalow: Male Gigolo  1999
# 3306  35466  GekijÃ´-ban poketto monsutÃ¢: Maboroshi no pok...  1999
# 3349  35854                                            Ringu 2  1999
# 3371  35996                                               ABCD  1999
# ...

# %%
movies_dates_clean_2=movies_dates_clean_2.rename(columns={"worlwide_gross_income": "gross_income"})
movies_dates_clean_2
# Out:
#       index                                              title  year  \
# 1434  24178                             Spontaneous Combustion  1990
# 1453  24301                    The Adventures of Ford Fairlane  1990
# 1454  24308                                        Air America  1990
# 1455  24310                                              Alice  1990
# 1456  24313                                    Almost an Angel  1990
# ...     ...                                                ...   ...
# 3280  35234                         Deuce Bigalow: Male Gigolo  1999
# 3306  35466  GekijÃ´-ban poketto monsutÃ¢: Maboroshi no pok...  1999
# 3349  35854                                            Ringu 2  1999
# 3371  35996                                               ABCD  1999
# 3372  36019                                     Los sin nombre  1999
#
#           budget gross_income
# 1434   $ 5500000      $ 50367
# 1453  $ 20000000   $ 21413502
# 1454  $ 35000000   $ 33461269
# ...

# %%
movies_dates_clean_2.drop(['index'], axis=1)
# Out:
#                                                   title  year      budget  \
# 1434                             Spontaneous Combustion  1990   $ 5500000
# 1453                    The Adventures of Ford Fairlane  1990  $ 20000000
# 1454                                        Air America  1990  $ 35000000
# 1455                                              Alice  1990  $ 12000000
# 1456                                    Almost an Angel  1990  $ 25000000
# ...                                                 ...   ...         ...
# 3280                         Deuce Bigalow: Male Gigolo  1999  $ 17000000
# 3306  GekijÃ´-ban poketto monsutÃ¢: Maboroshi no pok...  1999  $ 30000000
# 3349                                            Ringu 2  1999   $ 6000000
# 3371                                               ABCD  1999    $ 200000
# 3372                                     Los sin nombre  1999  EUR 900000
#
#      gross_income
# 1434      $ 50367
# 1453   $ 21413502
# 1454   $ 33461269
# ...
