# %%
# Dependencies
import pandas as pd
import datetime as dt

# %%
# Name of the CSV file
file = 'movies_metadata.csv'

# %%
meta_movies_df = pd.read_csv(file, encoding="ISO-8859-1")
# Out:
# C:\Users\hanso\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Preview of the DataFrame
meta_movies_df.head(3)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# 1           Jumanji  When siblings Judy and Peter discover an encha...  ...
# 2  Grumpier Old Men  A family wedding reignites the ancient feud be...  ...
#
#   release_date      revenue runtime  \
# 0   1995-10-30  373554033.0    81.0
# 1   1995-12-15  262797249.0   104.0
# 2   1995-12-22          0.0   101.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 0                                                NaN         Toy Story  False
# 1          Roll the dice and unleash the excitement!           Jumanji  False
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#   vote_average vote_count
# 0          7.7     5415.0
# 1          6.9     2413.0
# 2          6.5       92.0
#
# [3 rows x 24 columns]

# %%
meta_movies_df.count()
# Out:
# adult                    45466
# belongs_to_collection     4494
# budget                   45466
# genres                   45466
# homepage                  7782
# id                       45466
# imdb_id                  45449
# original_language        45455
# original_title           45466
# overview                 44512
# popularity               45461
# poster_path              45080
# production_companies     45463
# production_countries     45463
# release_date             45379
# revenue                  45460
# runtime                  45203
# spoken_languages         45460
# status                   45379
# tagline                  20412
# title                    45460
# video                    45460
# vote_average             45460
# vote_count               45460
# dtype: int64

# %%
meta_movies_df_clean=movies_df[['title', 'release_date','budget', 'revenue']].dropna()
meta_movies_df_clean=meta_movies_df_clean.reset_index()
meta_movies_df_clean
# Out:
#        index                        title release_date    budget      revenue
# 0          0                    Toy Story   1995-10-30  30000000  373554033.0
# 1          1                      Jumanji   1995-12-15  65000000  262797249.0
# 2          2             Grumpier Old Men   1995-12-22         0          0.0
# 3          3            Waiting to Exhale   1995-12-22  16000000   81452156.0
# 4          4  Father of the Bride Part II   1995-02-10         0   76578911.0
# ...      ...                          ...          ...       ...          ...
# 45371  45460                   Robin Hood   1991-05-13         0          0.0
# 45372  45462          Century of Birthing   2011-11-17         0          0.0
# 45373  45463                     Betrayal   2003-08-01         0          0.0
# 45374  45464             Satan Triumphant   1917-10-21         0          0.0
# 45375  45465                     Queerama   2017-06-09         0          0.0
#
# [45376 rows x 5 columns]

# %%
meta_movies_df_clean=meta_movies_df_clean.rename(columns={"revenue": "gross_income"})
meta_movies_df_clean=meta_movies_df_clean.rename(columns={"release_date": "year"})
meta_movies_df_clean=meta_movies_df_clean.drop(['index'], axis=1)
meta_movies_df_clean
# Out:
#                              title        year    budget  gross_income
# 0                        Toy Story  1995-10-30  30000000   373554033.0
# 1                          Jumanji  1995-12-15  65000000   262797249.0
# 2                 Grumpier Old Men  1995-12-22         0           0.0
# 3                Waiting to Exhale  1995-12-22  16000000    81452156.0
# 4      Father of the Bride Part II  1995-02-10         0    76578911.0
# ...                            ...         ...       ...           ...
# 45371                   Robin Hood  1991-05-13         0           0.0
# 45372          Century of Birthing  2011-11-17         0           0.0
# 45373                     Betrayal  2003-08-01         0           0.0
# 45374             Satan Triumphant  1917-10-21         0           0.0
# 45375                     Queerama  2017-06-09         0           0.0
#
# [45376 rows x 4 columns]

# %%
meta_movies_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45376 entries, 0 to 45375
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         45376 non-null  object
#  1   year          45376 non-null  object
#  2   budget        45376 non-null  object
#  3   gross_income  45376 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.4+ MB

# %%
meta_movies_df_clean2=meta_movies_df_clean[meta_movies_df_clean['gross_income']>0.0]
meta_movies_df_clean2
# Out:
#                              title        year    budget  gross_income
# 0                        Toy Story  1995-10-30  30000000   373554033.0
# 1                          Jumanji  1995-12-15  65000000   262797249.0
# 3                Waiting to Exhale  1995-12-22  16000000    81452156.0
# 4      Father of the Bride Part II  1995-02-10         0    76578911.0
# 5                             Heat  1995-12-15  60000000   187436818.0
# ...                            ...         ...       ...           ...
# 45311                  All at Once  2014-06-05    750000           3.0
# 45313                  The Miracle  2009-10-09         0       50656.0
# 45321                      Savages  2006-11-23    800000     1328612.0
# 45323                  Pro Lyuboff  2010-09-30   2000000     1268793.0
# 45333                      Antidur  2007-09-06   5000000     1413000.0
#
# [7407 rows x 4 columns]

# %%
meta_movies_df_clean3=meta_movies_df_clean2['budget'].astype(int)
budget_list=meta_movies_df_clean3.to_list()
budget_list
# Out:
# [30000000,
#  65000000,
#  16000000,
#  0,
#  60000000,
#  35000000,
#  58000000,
#  62000000,
#  0,
#  44000000,
#  98000000,
#  52000000,
#  16500000,
#  4000000,
#  30000000,
#  60000000,
#  30250000,
#  50000000,
#  3600000,
#  12000000,
#  18000000,
#  0,
#  29500000,
#  30000000,
#  11000000,
#  0,
#  18000000,
#  20000000,
#  10000000,
#  33000000,
#  55000000,
#  6000000,
#  15000000,
#  0,
#  0,
#  0,
#  3500000,
#  19000000,
#  50000000,
#  0,
#  0,
#  15000000,
#  20000000,
#  8000000,
#  38000000,
#  0,
#  8169363,
#  47000000,
#  14000000,
#  50000000,
#  7000000,
#  12000000,
#  24000000,
#  0,
#  72000000,
#  1300000,
#  7500000,
#  0,
#  25000000,
#  40000000,
#  7000000,
#  50000000,
#  0,
#  31000000,
#  19000000,
#  4000000,
#  52000000,
#  28000000,
#  100000000,
#  2000000,
#  11000000,
#  50000000,
#  25000000,
#  50000000,
#  53000000,
#  0,
#  7000000,
#  27000000,
#  90000000,
#  55000000,
#  20000000,
#  25000000,
#  90000000,
#  0,
#  1500000,
#  500000,
#  0,
#  6000000,
#  15000000,
#  2,
#  22000000,
#  0,
#  150000,
#  8,
#  50000000,
#  45000000,
#  7000000,
#  0,
#  35000000,
#  42000000,
#  14000000,
#  0,
#  0,
#  0,
#  60000000,
#  20000000,
#  175000000,
#  2800000,
#  0,
#  2500000,
#  10000000,
#  21000000,
#  27000,
#  25000000,
#  55000000,
#  16000000,
#  0,
#  0,
#  18000000,
#  0,
#  15000000,
#  0,
#  700000,
#  5000000,
#  10500000,
#  0,
#  60000000,
#  14000000,
#  60000000,
#  11000000,
#  2000000,
#  30000000,
#  17000000,
#  45000000,
#  0,
#  0,
#  6,
#  0,
#  31000000,
#  34000000,
#  0,
#  50000000,
#  16000000,
#  11000000,
#  8000000,
#  0,
#  400000,
#  0,
#  32000000,
#  22000000,
#  15000000,
#  35000000,
#  45000000,
#  55000000,
#  22000000,
#  25000000,
#  0,
#  25000000,
#  38000000,
#  6000000,
#  0,
#  11000000,
#  30000000,
#  17000000,
#  0,
#  3000000,
#  15000000,
#  0,
#  5000000,
#  62000000,
#  45000000,
#  15000000,
#  0,
#  46000000,
#  55000000,
#  6000000,
#  0,
#  0,
#  45000000,
#  0,
#  45000000,
#  35000000,
#  14000000,
#  23000000,
#  30000000,
#  11500000,
#  8000000,
#  30000000,
#  27000000,
#  115000000,
#  0,
#  63000000,
#  0,
#  10000000,
#  7000000,
#  35000000,
#  26000000,
#  8000000,
#  0,
#  34000000,
#  17080000,
#  0,
#  50000000,
#  0,
#  0,
#  13000000,
#  0,
#  22000000,
#  0,
#  13000000,
#  30000000,
#  0,
#  70000000,
#  40000000,
#  0,
#  6900000,
#  57000000,
#  0,
#  30000000,
#  42000000,
#  20000000,
#  44000000,
#  35000000,
#  0,
#  0,
#  18000000,
#  25000000,
#  0,
#  40000000,
#  13000000,
#  0,
#  0,
#  63000000,
#  9000000,
#  1500000,
#  85000000,
#  0,
#  0,
#  0,
#  13500000,
#  3500000,
#  55000000,
#  25000000,
#  12000000,
#  20000000,
#  30000000,
#  26000000,
#  7000000,
#  14000000,
#  0,
#  0,
#  11000000,
#  11500000,
#  40000000,
#  0,
#  22000000,
#  20000000,
#  11500000,
#  800000,
#  12000000,
#  22000000,
#  0,
#  13000000,
#  25000000,
#  0,
#  0,
#  21000000,
#  40000000,
#  28000000,
#  0,
#  20000000,
#  48000000,
#  7400000,
#  50000000,
#  18000000,
#  30000000,
#  25000000,
#  12500000,
#  27000000,
#  0,
#  0,
#  0,
#  18000000,
#  22000000,
#  28000000,
#  100000000,
#  22000000,
#  35000000,
#  19000000,
#  1488423,
#  25000000,
#  2600000,
#  14000000,
#  6244087,
#  0,
#  0,
#  7000000,
#  0,
#  4000000,
#  4000000,
#  0,
#  30000000,
#  0,
#  0,
#  12000000,
#  0,
#  46000000,
#  80000000,
#  57000000,
#  38000000,
#  13000000,
#  0,
#  0,
#  0,
#  80000000,
#  9000000,
#  25000000,
#  0,
#  30000000,
#  31000000,
#  25530000,
#  35000000,
#  15000000,
#  0,
#  4800000,
#  75000000,
#  92000000,
#  0,
#  0,
#  25000000,
#  1800000,
#  45000000,
#  50000000,
#  45000000,
#  0,
#  4000000,
#  75000000,
#  55000000,
#  100000000,
#  47000000,
#  27000000,
#  100000000,
#  54000000,
#  0,
#  80000000,
#  30000000,
#  5000000,
#  32000000,
#  3500000,
#  40000000,
#  0,
#  25000000,
#  13000000,
#  26000000,
#  80000000,
#  0,
#  0,
#  50000000,
#  36000000,
#  6000000,
#  13000000,
#  15000000,
#  6000000,
#  50000000,
#  2962051,
#  45000000,
#  200000,
#  6000000,
#  900000,
#  500000,
#  4500000,
#  60000000,
#  40000000,
#  25000000,
#  5000000,
#  2540800,
#  2723903,
#  2500000,
#  2479000,
#  1000000,
#  325000,
#  4000000,
#  3000000,
#  2883848,
#  4000000,
#  878000,
#  375000,
#  17000000,
#  2238813,
#  1500000,
#  2777000,
#  4000000,
#  1752000,
#  839727,
#  10500000,
#  1400000,
#  1688000,
#  1288000,
#  2000000,
#  1500000,
#  2500000,
#  1365000,
#  2033000,
#  1020000,
#  609000,
#  5400000,
#  1,
#  226408,
#  6000000,
#  3180000,
#  1500000,
#  114000,
#  1300000,
#  3000000,
#  0,
#  4,
#  0,
#  0,
#  25000000,
#  28000000,
#  0,
#  67000000,
#  9000000,
#  2300000,
#  38000000,
#  0,
#  50000000,
#  0,
#  5000000,
#  14000000,
#  0,
#  2900000,
#  3000000,
#  48000000,
#  6000000,
#  812000,
#  20000000,
#  3000000,
#  12000000,
#  8200000,
#  28000000,
#  10000000,
#  4500000,
#  0,
#  0,
#  16000000,
#  0,
#  65000000,
#  50000000,
#  2400000,
#  45000000,
#  7000000,
#  14500000,
#  200000,
#  44000000,
#  3000000,
#  2000000,
#  2000000,
#  7500000,
#  4000000,
#  0,
#  12000000,
#  2500000,
#  1400000,
#  6000000,
#  1200000,
#  6000000,
#  6500000,
#  49000000,
#  38000000,
#  3705538,
#  12500000,
#  12000000,
#  10500000,
#  60000000,
#  15000000,
#  0,
#  1800000,
#  12500000,
#  36000000,
#  0,
#  5000000,
#  6788000,
#  70000000,
#  1000000,
#  6000000,
#  1000000,
#  400000,
#  0,
#  0,
#  0,
#  7000000,
#  0,
#  0,
#  4000000,
#  0,
#  0,
#  0,
#  27000000,
#  0,
#  645180,
#  3000000,
#  4,
#  500000,
#  3000000,
#  0,
#  18000000,
#  16000000,
#  18000000,
#  18500000,
#  1200000,
#  350000,
#  15000000,
#  2200000,
#  2000000,
#  31500000,
#  5000000,
#  32350000,
#  2500000,
#  0,
#  25000000,
#  11000000,
#  11500000,
#  806948,
#  27000000,
#  13000000,
#  17000000,
#  18000000,
#  18000000,
#  4000000,
#  27000000,
#  14000000,
#  5500000,
#  6400000,
#  3000000,
#  18000000,
#  0,
#  14000000,
#  16400000,
#  3000000,
#  829000,
#  0,
#  3000000,
#  6000000,
#  3800000,
#  0,
#  19000000,
#  8000000,
#  3600000,
#  4000000,
#  15000000,
#  14600000,
#  14000000,
#  80000000,
#  0,
#  19000000,
#  11000000,
#  12000000,
#  8000000,
#  16000000,
#  3000000,
#  2800000,
#  3500000,
#  2000000,
#  2280000,
#  730000,
#  0,
#  15000000,
#  2500000,
#  0,
#  0,
#  48000000,
#  0,
#  22000000,
#  17000000,
#  3000000,
#  0,
#  12000000,
#  14400000,
#  1900000,
#  0,
#  6000000,
#  1746964,
#  16000000,
#  50000000,
#  10000000,
#  0,
#  0,
#  0,
#  0,
#  2500000,
#  40000000,
#  6000000,
#  35000000,
#  1800000,
#  1800000,
#  2800000,
#  0,
#  0,
#  46000000,
#  1000000,
#  60000000,
#  40000000,
#  3000000,
#  54000000,
#  70000000,
#  35000000,
#  27000000,
#  30000000,
#  12000000,
#  18000000,
#  24000000,
#  80000000,
#  13000000,
#  6000000,
#  13200000,
#  12000000,
#  35000000,
#  7000000,
#  20000000,
#  20500000,
#  70000000,
#  3000000,
#  50000000,
#  6000000,
#  0,
#  23000000,
#  14000000,
#  40000000,
#  0,
#  55000000,
#  0,
#  0,
#  0,
#  55000000,
#  0,
#  55000000,
#  0,
#  116000000,
#  0,
#  8000000,
#  0,
#  0,
#  0,
#  0,
#  50000000,
#  25000000,
#  15000000,
#  30000000,
#  35000000,
#  0,
#  0,
#  3000000,
#  28000000,
#  68000000,
#  45000000,
#  20000000,
#  90000000,
#  32000000,
#  0,
#  10000000,
#  35000000,
#  0,
#  45000000,
#  0,
#  0,
#  0,
#  16500000,
#  36000000,
#  90000000,
#  0,
#  0,
#  2000000,
#  0,
#  0,
#  73000000,
#  75000000,
#  160000000,
#  500000,
#  0,
#  125000000,
#  85000000,
#  38000000,
#  900000,
#  80000000,
#  90000000,
#  28000000,
#  90000000,
#  50000000,
#  20000000,
#  15000000,
#  60000000,
#  40000000,
#  3000000,
#  19000000,
#  75000000,
#  16000000,
#  30000000,
#  85000000,
#  20000000,
#  30000000,
#  0,
#  35000000,
#  70000000,
#  27000000,
#  5000000,
#  50000000,
#  60000000,
#  19000000,
#  0,
#  18000000,
#  250000,
#  0,
#  3500000,
#  17000000,
#  57000000,
#  12000000,
#  1500000,
#  0,
#  0,
#  36000000,
#  0,
#  0,
#  37000000,
#  0,
#  10000000,
#  18000000,
#  50000000,
#  24000000,
#  40000000,
#  15000000,
#  12000000,
#  105000000,
#  11000000,
#  6000000,
#  30000000,
#  60000000,
#  0,
#  60000000,
#  53000000,
#  20000000,
#  70000000,
#  36000000,
#  20000000,
#  80000000,
#  35000000,
#  10000000,
#  32000000,
#  35000000,
#  38000000,
#  24000000,
#  5000000,
#  200000000,
#  110000000,
#  80000000,
#  60000000,
#  12000000,
#  28000000,
#  15000000,
#  0,
#  25000000,
#  0,
#  15000000,
#  27000000,
#  0,
#  70000000,
#  8000000,
#  0,
#  3000000,
#  0,
#  25000000,
#  45000000,
#  30000000,
#  1000000,
#  28000000,
#  18000000,
#  75000000,
#  50000000,
#  1000000,
#  60000000,
#  0,
#  27000000,
#  20000000,
#  0,
#  0,
#  1000000,
#  15000000,
#  24000000,
#  0,
#  0,
#  80000000,
#  10000000,
#  55000000,
#  0,
#  25000000,
#  0,
#  5000000,
#  10000000,
#  12716953,
#  35000000,
#  0,
#  0,
#  13000000,
#  0,
#  0,
#  75000000,
#  13000000,
#  40000000,
#  130000000,
#  30000000,
#  18500000,
#  5000000,
#  60000000,
#  70000000,
#  10000000,
#  0,
#  180000,
#  0,
#  0,
#  90000000,
#  66000000,
#  71000000,
#  48000000,
#  1500000,
#  140000000,
#  140000000,
#  40000000,
#  60000,
#  23000000,
#  379000,
#  700000,
#  1180280,
#  1950000,
#  1644736,
#  1250000,
#  1344000,
#  0,
#  1250000,
#  2100000,
#  2000000,
#  4000000,
#  1650000,
#  910000,
#  343000,
#  6000000,
#  1000000,
#  3900000,
#  2000000,
#  10000000,
#  3600000,
#  1800000,
#  1000000,
#  8000000,
#  5500000,
#  31000000,
#  23000000,
#  25000000,
#  7500000,
#  1500000,
#  25000000,
#  1000000,
#  3000000,
#  5000000,
#  7000000,
#  8000000,
#  11000000,
#  550000,
#  1250000,
#  4000000,
#  2600000,
#  2200000,
#  3000000,
#  2800000,
#  5000000,
#  300000,
#  2500000,
#  2500000,
#  5000000,
#  5000000,
#  1000000,
#  0,
#  9000000,
#  13000000,
#  13000000,
#  10700000,
#  19000000,
#  10500000,
#  8000000,
#  14000000,
#  0,
#  15000000,
#  25000000,
#  35000000,
#  11000000,
#  50000000,
#  19000000,
#  95000000,
#  0,
#  92620000,
#  40000000,
#  40000000,
#  5000000,
#  858000,
#  2000000,
#  14000000,
#  40000000,
#  7000000,
#  54000000,
#  1227401,
#  62000000,
#  15000000,
#  10000000,
#  70000000,
#  0,
#  25000000,
#  20000000,
#  5000000,
#  0,
#  0,
#  0,
#  14000000,
#  28000000,
#  40000000,
#  32000000,
#  50000000,
#  0,
#  160000,
#  15000000,
#  11000000,
#  0,
#  0,
#  18000000,
#  6000000,
#  0,
#  4000000,
#  0,
#  40000000,
#  10000000,
#  0,
#  4000000,
#  4000000,
#  37931000,
#  1200000,
#  0,
#  25000000,
#  42000000,
#  6000000,
#  19000000,
#  8000000,
#  0,
#  17000000,
#  0,
#  17000000,
#  0,
#  0,
#  10500000,
#  10000000,
#  28000000,
#  4000000,
#  10000000,
#  10000000,
#  5000000,
#  800000,
#  13800000,
#  30000000,
#  26000000,
#  73000000,
#  300000,
#  7200000,
#  7500000,
#  0,
#  0,
#  18000000,
#  1000000,
#  7000000,
#  15000000,
#  9000000,
#  0,
#  25000000,
#  6500000,
#  0,
#  0,
#  0,
#  5000000,
#  0,
#  60000000,
#  20000000,
#  3200000,
#  27000000,
#  32000000,
#  5000000,
#  45000000,
#  0,
#  15000000,
#  1500000,
#  2000000,
#  3500000,
#  4000000,
#  3000000,
#  2135161,
#  ...]

# %%
meta_movies_df_clean2['Budget']=budget_list
meta_movies_df_clean2
# Out:
# C:\Users\hanso\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                              title        year    budget  gross_income  \
# 0                        Toy Story  1995-10-30  30000000   373554033.0
# 1                          Jumanji  1995-12-15  65000000   262797249.0
# 3                Waiting to Exhale  1995-12-22  16000000    81452156.0
# 4      Father of the Bride Part II  1995-02-10         0    76578911.0
# 5                             Heat  1995-12-15  60000000   187436818.0
# ...                            ...         ...       ...           ...
# 45311                  All at Once  2014-06-05    750000           3.0
# 45313                  The Miracle  2009-10-09         0       50656.0
# 45321                      Savages  2006-11-23    800000     1328612.0
# 45323                  Pro Lyuboff  2010-09-30   2000000     1268793.0
# 45333                      Antidur  2007-09-06   5000000     1413000.0
#
#          Budget
# 0      30000000
# 1      65000000
# 3      16000000
# 4             0
# 5      60000000
# ...         ...
# 45311    750000
# 45313         0
# 45321    800000
# 45323   2000000
# 45333   5000000
#
# [7407 rows x 5 columns]

# %%
meta_movies_df_clean3=meta_movies_df_clean2.drop(['budget'], axis=1)
meta_movies_df_clean3
# Out:
#                              title        year  gross_income    Budget
# 0                        Toy Story  1995-10-30   373554033.0  30000000
# 1                          Jumanji  1995-12-15   262797249.0  65000000
# 3                Waiting to Exhale  1995-12-22    81452156.0  16000000
# 4      Father of the Bride Part II  1995-02-10    76578911.0         0
# 5                             Heat  1995-12-15   187436818.0  60000000
# ...                            ...         ...           ...       ...
# 45311                  All at Once  2014-06-05           3.0    750000
# 45313                  The Miracle  2009-10-09       50656.0         0
# 45321                      Savages  2006-11-23     1328612.0    800000
# 45323                  Pro Lyuboff  2010-09-30     1268793.0   2000000
# 45333                      Antidur  2007-09-06     1413000.0   5000000
#
# [7407 rows x 4 columns]

# %%
meta_movies_df_clean3=meta_movies_df_clean3[meta_movies_df_clean3['Budget']>0.0]
meta_movies_df_clean3
# Out:
#                    title        year  gross_income    Budget
# 0              Toy Story  1995-10-30   373554033.0  30000000
# 1                Jumanji  1995-12-15   262797249.0  65000000
# 3      Waiting to Exhale  1995-12-22    81452156.0  16000000
# 5                   Heat  1995-12-15   187436818.0  60000000
# 8           Sudden Death  1995-12-22    64350171.0  35000000
# ...                  ...         ...           ...       ...
# 45163   Sivaji: The Boss  2007-06-14    19000000.0  12000000
# 45311        All at Once  2014-06-05           3.0    750000
# 45321            Savages  2006-11-23     1328612.0    800000
# 45323        Pro Lyuboff  2010-09-30     1268793.0   2000000
# 45333            Antidur  2007-09-06     1413000.0   5000000
#
# [5381 rows x 4 columns]

# %%
list_dates_all = meta_movies_df_clean3['year'].str.split('-').str.get(0).astype(int).tolist()
# Out:
# [1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1996, 1995, 1996, 1995, 1995, 1996, 1995, 1996, 1995, 1996, 1996, 1996, 1995, 1995, 1976, 1995, 1995, 1992, 1996, 1995, 1996, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1994, 1995, 1995, 1995, 1994, 1994, 1994, 1994, 1994, 1995, 1994, 1994, 1995, 1994, 1995, 1994, 1977, 1992, 1994, 1995, 1994, 1995, 1994, 1994, 1995, 1994, 1995, 1994, 1992, 1995, 1995, 1994, 1994, 1994, 1994, 1994, 1994, 1995, 1994, 1995, 1993, 1995, 1995, 1994, 1994, 1992, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1993, 1994, 1994, 1994, 1994, 1993, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1993, 1994, 1994, 1993, 1993, 1993, 1993, 1993, 1994, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1993, 1996, 1993, 1994, 1994, 1993, 1993, 1993, 1993, 1994, 1993, 1994, 1993, 1993, 1993, 1993, 1993, 1993, 1994, 1994, 1993, 1993, 1982, 1993, 1993, 1994, 1994, 1993, 1993, 1993, 1993, 1994, 1990, 1990, 1992, 1991, 1990, 1989, 1991, 1937, 1991, 1940, 1990, 1969, 1996, 1996, 1970, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1968, 1996, 1996, 1988, 1996, 1995, 1996, 1996, 1996, 1996, 1996, 1964, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1991, 1972, 1992, 1996, 1996, 1997, 1996, 1996, 1995, 1952, 1951, 1961, 1958, 1954, 1934, 1959, 1960, 1959, 1963, 1942, 1941, 1964, 1954, 1953, 1939, 1939, 1950, 1941, 1968, 1950, 1939, 1940, 1946, 1945, 1955, 1939, 1938, 1944, 1935, 1956, 1955, 1934, 1956, 1946, 1939, 1968, 1951, 1958, 1932, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1954, 1993, 1950, 1963, 1991, 1964, 1941, 1971, 1951, 1981, 1965, 1988, 1992, 1996, 1996, 1996, 1996, 1996, 1997, 1996, 1996, 1996, 1996, 1971, 1973, 1971, 1988, 1979, 1965, 1967, 1954, 1987, 1992, 1986, 1989, 1992, 1991, 1992, 1992, 1982, 1982, 1990, 1986, 1951, 1996, 1996, 1975, 1991, 1989, 1980, 1981, 1981, 1975, 1996, 1991, 1996, 1989, 1992, 1991, 1990, 1975, 1980, 1987, 1981, 1986, 1966, 1957, 1962, 1971, 1962, 1979, 1968, 1983, 1987, 1990, 1979, 1985, 1960, 1980, 1974, 1987, 1984, 1980, 1977, 1983, 1981, 1973, 1984, 1992, 1989, 1990, 1989, 1967, 1958, 1957, 1974, 1948, 1980, 1986, 1987, 1963, 1978, 1993, 1992, 1962, 1985, 1991, 1970, 1988, 1986, 1967, 1974, 1991, 1940, 1940, 1952, 1959, 1984, 1989, 1982, 1988, 1985, 1982, 1984, 1956, 1969, 1984, 1989, 1992, 1981, 1963, 1992, 1992, 1991, 1976, 1984, 1976, 1996, 1996, 1996, 1996, 1996, 1996, 1990, 1979, 1991, 1989, 1982, 1984, 1986, 1992, 1988, 1978, 1982, 1990, 1992, 1975, 1978, 1983, 1996, 1996, 1996, 1987, 1996, 1996, 1992, 1996, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1996, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1963, 1997, 1997, 1997, 1997, 1997, 1982, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1990, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1981, 1997, 1997, 1997, 1997, 1997, 1985, 1997, 1993, 1998, 1997, 1998, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1997, 1998, 1997, 1997, 1998, 1998, 1997, 1998, 1998, 1998, 1997, 1997, 1998, 1998, 1997, 1998, 1998, 1998, 1997, 1990, 1998, 1998, 1998, 1997, 1998, 1998, 1998, 1997, 1998, 1998, 1998, 1998, 1997, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1997, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1929, 1932, 1933, 1935, 1938, 1941, 1942, 1945, 1946, 1947, 1952, 1953, 1954, 1955, 1961, 1963, 1966, 1967, 196 ...

# %%
meta_movies_df_clean3['Year']=list_dates_all
meta_movies_df_clean3
# Out:
# C:\Users\hanso\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                    title        year  gross_income    Budget  Year
# 0              Toy Story  1995-10-30   373554033.0  30000000  1995
# 1                Jumanji  1995-12-15   262797249.0  65000000  1995
# 3      Waiting to Exhale  1995-12-22    81452156.0  16000000  1995
# 5                   Heat  1995-12-15   187436818.0  60000000  1995
# 8           Sudden Death  1995-12-22    64350171.0  35000000  1995
# ...                  ...         ...           ...       ...   ...
# 45163   Sivaji: The Boss  2007-06-14    19000000.0  12000000  2007
# 45311        All at Once  2014-06-05           3.0    750000  2014
# 45321            Savages  2006-11-23     1328612.0    800000  2006
# 45323        Pro Lyuboff  2010-09-30     1268793.0   2000000  2010
# 45333            Antidur  2007-09-06     1413000.0   5000000  2007
#
# [5381 rows x 5 columns]

# %%
meta_movies_df_clean4=meta_movies_df_clean3[(meta_movies_df_clean3['Year']> 1989)]
meta_movies_df_clean4
# Out:
#                    title        year  gross_income    Budget  Year
# 0              Toy Story  1995-10-30   373554033.0  30000000  1995
# 1                Jumanji  1995-12-15   262797249.0  65000000  1995
# 3      Waiting to Exhale  1995-12-22    81452156.0  16000000  1995
# 5                   Heat  1995-12-15   187436818.0  60000000  1995
# 8           Sudden Death  1995-12-22    64350171.0  35000000  1995
# ...                  ...         ...           ...       ...   ...
# 45163   Sivaji: The Boss  2007-06-14    19000000.0  12000000  2007
# 45311        All at Once  2014-06-05           3.0    750000  2014
# 45321            Savages  2006-11-23     1328612.0    800000  2006
# 45323        Pro Lyuboff  2010-09-30     1268793.0   2000000  2010
# 45333            Antidur  2007-09-06     1413000.0   5000000  2007
#
# [4362 rows x 5 columns]

# %%
meta_movies_df_clean5=meta_movies_df_clean4[(meta_movies_df_clean4['Year']< 2000)]

meta_movies_df_clean5
# Out:
#                     title        year  gross_income    Budget  Year
# 0               Toy Story  1995-10-30   373554033.0  30000000  1995
# 1                 Jumanji  1995-12-15   262797249.0  65000000  1995
# 3       Waiting to Exhale  1995-12-22    81452156.0  16000000  1995
# 5                    Heat  1995-12-15   187436818.0  60000000  1995
# 8            Sudden Death  1995-12-22    64350171.0  35000000  1995
# ...                   ...         ...           ...       ...   ...
# 38219               Aasai  1995-09-25      500000.0    500000  1995
# 38220       Kadhal Kottai  1996-07-12      500000.0    500000  1996
# 38628                Paws  1997-09-25     1778391.0    137731  1997
# 39656  The Cherry Orchard  1999-01-01         135.0         5  1999
# 44344           Mudhalvan  1999-11-07    22000000.0   7400000  1999
#
# [942 rows x 5 columns]

# %%
meta_movies_df_clean6=meta_movies_df_clean5.rename(columns={"Budget": "budget"})

meta_movies_df_clean7=meta_movies_df_clean6.drop(['year'], axis=1)

meta_movies_df_clean8=meta_movies_df_clean7.rename(columns={"Year": "year"})
meta_movies_df_clean8
# Out:
#                     title  gross_income    budget  year
# 0               Toy Story   373554033.0  30000000  1995
# 1                 Jumanji   262797249.0  65000000  1995
# 3       Waiting to Exhale    81452156.0  16000000  1995
# 5                    Heat   187436818.0  60000000  1995
# 8            Sudden Death    64350171.0  35000000  1995
# ...                   ...           ...       ...   ...
# 38219               Aasai      500000.0    500000  1995
# 38220       Kadhal Kottai      500000.0    500000  1996
# 38628                Paws     1778391.0    137731  1997
# 39656  The Cherry Orchard         135.0         5  1999
# 44344           Mudhalvan    22000000.0   7400000  1999
#
# [942 rows x 4 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
meta_movies_df_clean8.to_csv("meta_movies_cleaned.csv", index=False, header=True)
